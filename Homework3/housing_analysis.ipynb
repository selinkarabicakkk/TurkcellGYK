# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("HousingData.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB
# None

# %%
print(df.isnull().sum())
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
imputer = SimpleImputer(strategy="mean")  
df.iloc[:, :] = imputer.fit_transform(df)

# %%
print(df.isnull().sum())
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.to_csv("HousingData_Clean.csv", index=False)

# %%
df_clean = pd.read_csv("HousingData_Clean.csv")

# %%
print(df_clean.isnull().sum())
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["AGE"], y=df["MEDV"])
plt.xlabel("Bina Yaşı (AGE)")
plt.ylabel("Ev Fiyatı (MEDV)")
plt.title("Bina Yaşı ile Ev Fiyatı İlişkisi")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["LSTAT"], y=df["MEDV"])
plt.xlabel("Düşük Sosyoekonomik Statü (%) (LSTAT)")
plt.ylabel("Ev Fiyatı (MEDV)")
plt.title("LSTAT ile Ev Fiyatı İlişkisi")
plt.show()
